# %% [markdown]
# 2025.10.20
#
# isaac_0.1 example using hugging face transformers
#
#
# I plan to first examine the structure of this model and how it works well with hugging face.
# - in the process, I expect to learn how hugging face works
# - in the process, I expect to review the Andrej structure of hugging face. He checked hugging face api in the view, right?
# - in the process, I expect to check the dependency to the perceptron sdk.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, AutoConfig
from huggingface.modular_isaac import IsaacProcessor

tokenizer = AutoTokenizer.from_pretrained("PerceptronAI/Isaac-0.1", trust_remote_code=True)
